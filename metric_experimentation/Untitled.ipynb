# %%
import numpy as np
import netCDF4 as nc
from os import getcwd, listdir
from os.path import join, dirname, isdir

# %%
import matplotlib.pyplot as plt

# %%
def signaltonoise(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)

# %%
data_path = join(dirname(getcwd()), 'data')

# %%
data_path = join(data_path, listdir(data_path)[0])

# %%
data_path = join(data_path, listdir(data_path)[0])

# %%
ds = nc.Dataset(data_path)

# %%
data = np.array(ds['amplitude_high_gain'])[0:]

# %%
signaltonoise(data).shape
# Out:
# (3200,)

# %%
plt.plot(signaltonoise(data))

# %%
plt.plot(signaltonoise(data,axis=1))
